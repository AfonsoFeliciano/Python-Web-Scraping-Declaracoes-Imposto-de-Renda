# %% [markdown]
# ### Versões do ambiente utilizado

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importando os pacotes

# %%
import requests
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import time
import datetime
import os

# %% [markdown]
# ### Definindo os anos que serão coletados para então descobrir quais UFs possuem anos com valores

# %%
anos = ['2021', '2022', '2023']

lista_ufs_anos = []

for ano in anos:

  today = datetime.date.today()
  ano_atual = str(today.year)

  if ano == ano_atual:
    url = f"https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_UF.HTML"
  else:
    url = f"https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_UF_{ano}.HTML"

  ufs = requests.get(url)
  print("Buscando dados no link: " + url)
  time_wait = 0.5
  print(f"Aguardando {time_wait} segundo (s).. \n")
  time.sleep(1)

  html_uf = ufs.text
  soup_uf = BeautifulSoup(html_uf, 'html.parser')

  html_final_uf = soup_uf.find_all('tr', {'class':['head even', 'head odd']})
  
  for i in soup_uf.find_all('a'):
    if len(i.text) == 2:
      lista_ufs_anos.append({"ano": ano, "uf": i.text})
# Out:
# Buscando dados no link: https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_UF_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link: https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_UF_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link: https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_UF.HTML
# Aguardando 0.5 segundo (s)..

# %% [markdown]
# ### Exibindo a lista de anos e UFs associadas
#
# Poderá ser observado uma lista de dicionários com todos os anos e UFs que possuem valores disponíveis

# %%
lista_ufs_anos
# Out:
# [{'ano': '2021', 'uf': 'AC'},
#  {'ano': '2021', 'uf': 'AL'},
#  {'ano': '2021', 'uf': 'AM'},
#  {'ano': '2021', 'uf': 'AP'},
#  {'ano': '2021', 'uf': 'BA'},
#  {'ano': '2021', 'uf': 'CE'},
#  {'ano': '2021', 'uf': 'DF'},
#  {'ano': '2021', 'uf': 'ES'},
#  {'ano': '2021', 'uf': 'GO'},
#  {'ano': '2021', 'uf': 'MA'},
#  {'ano': '2021', 'uf': 'MG'},
#  {'ano': '2021', 'uf': 'MS'},
#  {'ano': '2021', 'uf': 'MT'},
#  {'ano': '2021', 'uf': 'PA'},
#  {'ano': '2021', 'uf': 'PB'},
#  {'ano': '2021', 'uf': 'PE'},
#  {'ano': '2021', 'uf': 'PI'},
#  {'ano': '2021', 'uf': 'PR'},
#  {'ano': '2021', 'uf': 'RJ'},
#  {'ano': '2021', 'uf': 'RN'},
#  {'ano': '2021', 'uf': 'RO'},
#  {'ano': '2021', 'uf': 'RR'},
#  {'ano': '2021', 'uf': 'RS'},
#  {'ano': '2021', 'uf': 'SC'},
#  {'ano': '2021', 'uf': 'SE'},
#  {'ano': '2021', 'uf': 'SP'},
#  {'ano': '2021', 'uf': 'TO'},
#  {'ano': '2022', 'uf': 'AC'},
#  {'ano': '2022', 'uf': 'AL'},
#  {'ano': '2022', 'uf': 'AM'},
#  {'ano': '2022', 'uf': 'AP'},
#  {'ano': '2022', 'uf': 'BA'},
#  {'ano': '2022', 'uf': 'CE'},
#  {'ano': '2022', 'uf': 'DF'},
#  {'ano': '2022', 'uf': 'ES'},
#  {'ano': '2022', 'uf': 'GO'},
#  {'ano': '2022', 'uf': 'MA'},
#  {'ano': '2022', 'uf': 'MG'},
#  {'ano': '2022', 'uf': 'MS'},
#  {'ano': '2022', 'uf': 'MT'},
#  {'ano': '2022', 'uf': 'PA'},
#  {'ano': '2022', 'uf': 'PB'},
#  {'ano': '2022', 'uf': 'PE'},
#  {'ano': '2022', 'uf': 'PI'},
#  {'ano': '2022', 'uf': 'PR'},
#  {'ano': '2022', 'uf': 'RJ'},
#  {'ano': '2022', 'uf': 'RN'},
#  {'ano': '2022', 'uf': 'RO'},
#  {'ano': '2022', 'uf': 'RR'},
#  {'ano': '2022', 'uf': 'RS'},
#  {'ano': '2022', 'uf': 'SC'},
#  {'ano': '2022', 'uf': 'SE'},
#  {'ano': '2022', 'uf': 'SP'},
#  {'ano': '2022', 'uf': 'TO'},
#  {'ano': '2023', 'uf': 'AC'},
#  {'ano': '2023', 'uf': 'AL'},
#  {'ano': '2023', 'uf': 'AM'},
#  {'ano': '2023', 'uf': 'AP'},
#  {'ano': '2023', 'uf': 'BA'},
#  {'ano': '2023', 'uf': 'CE'},
#  {'ano': '2023', 'uf': 'DF'},
#  {'ano': '2023', 'uf': 'ES'},
#  {'ano': '2023', 'uf': 'GO'},
#  {'ano': '2023', 'uf': 'MA'},
#  {'ano': '2023', 'uf': 'MG'},
#  {'ano': '2023', 'uf': 'MS'},
#  {'ano': '2023', 'uf': 'MT'},
#  {'ano': '2023', 'uf': 'PA'},
#  {'ano': '2023', 'uf': 'PB'},
#  {'ano': '2023', 'uf': 'PE'},
#  {'ano': '2023', 'uf': 'PI'},
#  {'ano': '2023', 'uf': 'PR'},
#  {'ano': '2023', 'uf': 'RJ'},
#  {'ano': '2023', 'uf': 'RN'},
#  {'ano': '2023', 'uf': 'RO'},
#  {'ano': '2023', 'uf': 'RR'},
#  {'ano': '2023', 'uf': 'RS'},
#  {'ano': '2023', 'uf': 'SC'},
#  {'ano': '2023', 'uf': 'SE'},
#  {'ano': '2023', 'uf': 'SP'},
#  {'ano': '2023', 'uf': 'TO'}]

# %% [markdown]
# ### Realizando a coleta informando os Anos e UFs para retornar as Cidades

# %%
lista_valores = []

for i in lista_ufs_anos:
  ano = i["ano"]
  uf = i["uf"]
  url = f"https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_{uf}_{ano}.HTML"
  time_wait = 0.5
  print("Buscando dados no link: ", url)
  print(f"Aguardando {time_wait} segundo (s).. \n")
  time.sleep(time_wait)
  cidades = requests.get(url)

  html = cidades.text
  soup = BeautifulSoup(html, 'html.parser')
  html_final = soup.find_all('tr', {'class':['head even', 'head odd']})

  
  for i in (html_final):
    if "Meio\nTributação\nTipo\nResultado" not in i.get_text() and "UF\nTotal" not in i.get_text():
      lista_valores.append( (i.get_text() + uf +"\n" + ano).split('\n'))
# Out:
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AC_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AL_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AM_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AP_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_BA_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_CE_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_DF_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_ES_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_GO_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MA_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MG_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MS_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MT_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PA_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PB_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PE_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PI_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PR_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RJ_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RN_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RO_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RR_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RS_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SC_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SE_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SP_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_TO_2021.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AC_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AL_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AM_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AP_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_BA_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_CE_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_DF_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_ES_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_GO_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MA_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MG_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MS_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MT_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PA_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PB_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PE_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PI_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PR_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RJ_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RN_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RO_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RR_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RS_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SC_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SE_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SP_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_TO_2022.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AC_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AL_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AM_2023.HTML
# Aguardando 0.5 segundo (s)..
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_AP_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_BA_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_CE_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_DF_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_ES_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_GO_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MA_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MG_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MS_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_MT_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PA_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PB_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PE_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PI_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_PR_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RJ_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RN_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RO_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RR_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_RS_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SC_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SE_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_SP_2023.HTML
# Aguardando 0.5 segundo (s)..
#
# Buscando dados no link:  https://servicos.receita.fazenda.gov.br/publico/EstatisticaIRPF/totaisDIRPF_TO_2023.HTML
# Aguardando 0.5 segundo (s)..

# %% [markdown]
# ### Particularidades
#
# Como a Receita Federal Brasileira (RFB) possui diversas mudanças no decorrer dos anos, é normal que os dados coletados possuam divergências. Após algumas análises, foi observado que os dados de 2021 e 2022 não sofreram alterações, porém 2023, possui algumas colunas adicionais. Desse modo a lógica abaixo foi implementada, optando inicialmente pelo número de elementos na lista.
#
# Em 2021 e 2022 o número de colunas são 15, porém para 2023 o número foi aumentado.

# %%
lista_2021_2022 = []
lista_2023 = []

for i in lista_valores: 
  if len(i) == 15:
    lista_2021_2022.append(i)
  else:
    lista_2023.append(i)

# %% [markdown]
# ### Definindo as colunas para cada ano e criando os DataFrames

# %%
colunas_2021_2022 = ["Cidade", "Total", "Pré-Preenchida", "PGD", "APP", "Online", "Deduções", "Simplificada", "Originais", "Retificadoras", "Sem Imposto", "A pagar", "A restituir", "UF", "Ano"]
colunas_2023 = ["Cidade", "Total", "Pré-Preenchida", "PGD", "APP", "Online", "Deduções", "Simplificada", "Originais", "Retificadoras", "Sem Imposto", "A pagar", "A restituir", "Conta", "Pix", "UF", "Ano"]

df_2021_2022 = pd.DataFrame(lista_2021_2022, columns = colunas_2021_2022)
df_2023 = pd.DataFrame(lista_2023, columns = colunas_2023)

df_final = df_2021_2022.merge(df_2023, how = 'outer')

# %% [markdown]
# ### Salvando o dataframe em arquivo Excel para análises

# %%
path_dados_consolidados = "data/dados_consolidados/"

path_dados_consolidados_exists = os.path.exists(path_dados_consolidados)
if not path_dados_consolidados_exists:

   # Create a new directory because it does not exist
   os.makedirs(path_dados_consolidados)
   print("Criando diretório: ", path_dados_consolidados)

df_final.to_excel(f"{path_dados_consolidados}dados_imposto_de_renda.xlsx", index=False)
print("Salvando arquivo excel no diretório: ", path_dados_consolidados)
# Out:
# Criando diretório:  data/dados_consolidados/
